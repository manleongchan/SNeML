# %% [markdown]
# # This page shows the
# # 1. results from a CNN trained using simulated waveforms
# # 2. results for applying the CNN on waveforms that were used to trained the CNN
# #
# # The network is H+ L+ V K

# %%
import Image
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
import numpy as np

# %% [markdown]
# # Figure 1. Detection/Classification efficiency for the two explosion mechanisms.
# # Left panel: magnetorotational explosion mechanism. Right panel: neutrino-driven mechanism

# %%
fig, ax1 = plt.subplots(1,2, figsize=(41.,41), sharex = False)
gs1 = gridspec.GridSpec(4, 4)
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1], wspace=0.0, hspace=-10.0, top=0.95, bottom=0.05, left=0.17, right=0.845) 
ax1[0].imshow(img)
ax1[1].imshow(img2)

for i in range(len(ax1)):
    ax1[i].patch.set_visible(False)
    ax1[i].axis('off')
    #ax1[i].set_aspect('equal')

# %% [markdown]
# # Figure 2. Classification efficiency of the CNN applied to waveforms that were not used to train the CNN
# # magnetorotational waveforms: R3E1AC R4E1FC_L from Scheidegger, et al, 2010
# # neutrino-driven waveforms: SFHx from and Kuroda, et al, 2016 and s20s from Andresen, et al, 2016
# #

# %%
fig, ax1 = plt.subplots(1,1, figsize=(41.,41))
gs1 = gridspec.GridSpec(4, 4)
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1], wspace=0.0, hspace=-10.0, top=0.95, bottom=0.05, left=0.17, right=0.845) 
ax1.imshow(img)
ax1.patch.set_visible(False)
ax1.axis('off')
# Out:
# (-0.5, 2049.5, 1124.5, -0.5)
